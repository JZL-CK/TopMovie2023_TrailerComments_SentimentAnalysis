# %%
dev = "dev_id"

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="id",
    maxResults=100
)

comments = []

# Execute the request.
response = request.execute()

# Get the comments from the response.
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

while (1 == 1):
  try:
   nextPageToken = response['nextPageToken']
  except KeyError:
   break
  nextPageToken = response['nextPageToken']
  # Create a new request object with the next page token.
  nextRequest = youtube.commentThreads().list(part="snippet", videoId="id", maxResults=100, pageToken=nextPageToken)
  # Execute the next request.
  response = nextRequest.execute()
  # Get the comments from the next response.
  for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

df = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','public'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11260 entries, 0 to 11259
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   author      11260 non-null  object
#  1   updated_at  11260 non-null  object
#  2   like_count  11260 non-null  int64
#  3   text        11260 non-null  object
#  4   public      11260 non-null  bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 363.0+ KB

# %%
response['items'][0]
# Out:
# {'kind': 'youtube#commentThread',
#  'etag': 'tfDRO_DV1Lkyvk_7kRYil9Lb0JQ',
#  'id': 'Ugwk_-zpqTzYsqmhN6F4AaABAg',
#  'snippet': {'channelId': 'UCvC4D8onUfXzvjTOM-dBfEA',
#   'videoId': 'JqcncLPi9zw',
#   'topLevelComment': {'kind': 'youtube#comment',
#    'etag': 'UBnD2PIwNTeKoE7YhrQCfStnGQI',
#    'id': 'Ugwk_-zpqTzYsqmhN6F4AaABAg',
#    'snippet': {'channelId': 'UCvC4D8onUfXzvjTOM-dBfEA',
#     'videoId': 'JqcncLPi9zw',
#     'textDisplay': 'WE ARE ESTING SO GOOD',
#     'textOriginal': 'WE ARE ESTING SO GOOD',
#     'authorDisplayName': '@slycordd',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_m9xQe8YDzkkCPTPSW7PSy1ZUQBEkfKKPJ3kaxOUozmVJcV=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@slycordd',
#     'authorChannelId': {'value': 'UC5jZBkHn7XF6fbNEHgyGjHQ'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 0,
#     'publishedAt': '2023-02-12T23:39:12Z',
#     'updatedAt': '2023-02-12T23:39:12Z'}},
#   'canReply': True,
#   'totalReplyCount': 0,
#   'isPublic': True}}

# %%
df.head(10)
# Out:
#                     author            updated_at  like_count  \
# 0           @BirdNerdFilms  2024-05-25T13:42:45Z           0
# 1         @randomchaos5216  2024-05-09T19:22:11Z           2
# 2                @ryanOGab  2024-05-06T09:15:58Z           1
# 3         @user-dr2yz8um3d  2024-05-05T23:05:40Z           1
# 4          @Gudise_kumar_7  2024-04-29T18:56:26Z           0
# 5      @ethanengelking2492  2024-04-21T02:12:11Z           1
# 6         @user-gz3kg9mh8m  2024-03-27T05:52:34Z           0
# 7            @cubanlinx936  2024-03-23T09:28:03Z          15
# 8  @martinperezdisalvo7611  2024-03-22T19:39:34Z           2
# 9              @EZboy44351  2024-03-20T00:04:35Z          13
#
#                                                 text  public
# 0  This movie was so much fun. It was dark but en...    True
# 1                        james gunn cooked with this    True
# 2     One year to the day 😢 it was an amazing ending    True
# 3  1 year old already!!!\n\nI saw this with my ol...    True
# 4  I heard that the story of vol: 3 is given by a...    True
# 5  When I hear “Since you’ve been gone” I instant...    True
# 6  What use do these various Zootopia Pets X's Mu...    True
# 7  Still don’t understand how this has less views...    True
# 8                                               1:50    True
# 9  The movie wasnt good..or great...it was absolu...    True

# %%
print(len(df))
# Out:
# 11260

# %%
# Saving it to csv file

import pandas as pd

# Assuming df is your DataFrame
# df = ...

# Write the DataFrame to a CSV file
df.to_csv('Movie_name.csv', index=False)

# Download the CSV file to your local machine
from google.colab import files
files.download('Movie_name.csv')
